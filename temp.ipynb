# %%
import pandas as pd
df = pd.read_csv("parking_data.csv")

df.head(50)
# Out:
#                    time  hour  base_demand  payments_started  payments_ended  \
# 0   2024-01-01 00:00:00     0     0.000481                 0               0
# 1   2024-01-01 00:05:00     0     0.000481                 0               0
# 2   2024-01-01 00:10:00     0     0.000481                 0               0
# 3   2024-01-01 00:15:00     0     0.000481                 0               0
# 4   2024-01-01 00:20:00     0     0.000481                 0               0
# 5   2024-01-01 00:25:00     0     0.000481                 0               0
# 6   2024-01-01 00:30:00     0     0.000481                 0               0
# 7   2024-01-01 00:35:00     0     0.000481                 0               0
# 8   2024-01-01 00:40:00     0     0.000481                 0               0
# 9   2024-01-01 00:45:00     0     0.000481                 0               0
# 10  2024-01-01 00:50:00     0     0.000481                 0               0
# ...
